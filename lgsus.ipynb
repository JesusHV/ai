# %% [markdown]
# <a href="https://colab.research.google.com/github/JesusHV/ai/blob/main/lgsus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

from sklearn.datasets import make_circles

# Create dataset
n_numberOfRegisters = 500
p_numberOfCharacteristics = 2

X,Y = make_circles(n_samples=n_numberOfRegisters, factor=0.5)

plt.scatter(X[:, 0], X[:, 1])

plt.show()
